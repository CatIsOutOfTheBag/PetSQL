# %%
import sqlite3 # импорт встроенной БД

# %%
con = sqlite3.connect('db') # подключение БД

# %%
import pandas as pd

# %%
df = pd.DataFrame({'col1': [1,2,3]})

# %%
df
# Out:
#    col1
# 0     1
# 1     2
# 2     3

# %%
# залить датафрейм в базу
# без индекса
# если уже было залито - заменить
df.to_sql('test_table', con, index=False, if_exists='replace')

# %%
# запрос к БД
sql = '''select
* from 
test_table t''' # запрос

# %%
pd.read_sql(sql, con) # отправить запрос
# Out:
#    col1
# 0     1
# 1     2
# 2     3

# %%
# другой запрос к БД
sql = '''select
t.col1 * 3 as mult_3 from 
test_table t''' # запрос

# %%
pd.read_sql(sql, con) # отправить запрос
# Out:
#    mult_3
# 0       3
# 1       6
# 2       9

# %%
# построим график того, что пришло с sql
pd.read_sql(sql, con).plot()

# %%
# не важно, какая БД. SQL один на всех
'''
- oracle
- mysql
- postgres
- ms sql server
- sqlite3
''';

# %% [markdown]
# # Заливка данных

# %%
# sqlite3 нужно обновить
# !gdown --id 1BSHIKQ7rFw5BpTq5nw1UZfjPK_7Mpnbi
# !mv _sqlite3.cpython-37m-x86_64-linux-gnu.so /usr/lib/python3.7/lib-dynload/
import os
os.kill(os.getpid(), 9)
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1BSHIKQ7rFw5BpTq5nw1UZfjPK_7Mpnbi
# To: /content/_sqlite3.cpython-37m-x86_64-linux-gnu.so
# 100% 6.50M/6.50M [00:00<00:00, 194MB/s]

# %%
import pandas as pd
import numpy as np
import sqlite3

# %%
con = sqlite3.connect('db')

# %% [markdown]
# Заливаем данные
#
# Ссылка для скачивания данных на Google Drive
# https://drive.google.com/file/d/1Gj0qVU0Acv-HqRjTIEwvkO4TqJYijehR/view?usp=sharing

# %%
# !gdown --id 1Gj0qVU0Acv-HqRjTIEwvkO4TqJYijehR
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1Gj0qVU0Acv-HqRjTIEwvkO4TqJYijehR
# To: /content/german_credit_augmented.csv
# 100% 69.6k/69.6k [00:00<00:00, 46.2MB/s]

# %%
df = pd.read_csv('/content/german_credit_augmented.csv')

# %%
df.head()
# Out:
#    age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0   33    male    2     own             NaN              NaN           3074
# 1   43    male    1     own          little           little           1344
# 2   52    male    2     own      quite rich              NaN            936
# 3   35  female    3     own          little              NaN           1393
# 4   28    male    2     own          little              NaN            776
#
#    duration    purpose  default          contract_dt  client_id
# 0         9   radio/TV        0  2008-06-29 18:52:00        210
# 1        12        car        0  2007-05-20 18:30:19        929
# 2         9  education        0  2008-04-27 08:23:07        200
# 3        11        car        0  2007-05-06 10:58:22         45
# 4        12   radio/TV        0  2007-07-21 13:22:14        358

# %%
# Обязательно нужно контролировать тип ДАТА, так как он заливается просто как текст
df['contract_dt'] = pd.to_datetime(df['contract_dt'], format='%Y-%m-%d %H:%M:%S')

# %%
df.dtypes
# Out:
# age                          int64
# sex                         object
# job                          int64
# housing                     object
# saving_accounts             object
# checking_account            object
# credit_amount                int64
# duration                     int64
# purpose                     object
# default                      int64
# contract_dt         datetime64[ns]
# client_id                    int64
# dtype: object

# %%
# сделали mount гугл-диска
# посмотрим что на диске
! ls '/content/drive/My Drive'
# Out:
#  Churn_Modelling.csv   german_credit.db   test-bd.gsheet
# 'Colab Notebooks'      hr_analytics.zip   UK-used-cars.zip

# %%
# создадим файл с базой данных на гугл-диске
con = sqlite3.connect('/content/drive/My Drive/german_credit.db')

# %%
! ls '/content/drive/My Drive'
# Out:
#  Churn_Modelling.csv   german_credit.db   test-bd.gsheet
# 'Colab Notebooks'      hr_analytics.zip   UK-used-cars.zip

# %%
df.to_sql('german_credit', con, index=False, if_exists='replace')

# %% [markdown]
# # Postgress

# %% [markdown]
# Postgess для работы с ней должен быть где-то запущен.
#
# Простой вариант - ElephantSQL
# https://www.elephantsql.com/

# %% [markdown]
# URL postgress базы
#
#
# postgres://mzsexmlj:HnO7Ku7fy_6VCtQM9uUSVECvXKc4WILU@abul.db.elephantsql.com/mzsexmlj

# %%
from sqlalchemy import create_engine
con = create_engine('postgresql+psycopg2://mzsexmlj:HnO7Ku7fy_6VCtQM9uUSVECvXKc4WILU@abul.db.elephantsql.com/mzsexmlj')

# %%
# в postgres датафреймы заливаются в базу очень медленно. Есть вот такой ускоритель:
import csv
from io import StringIO

from sqlalchemy import create_engine

def psql_insert_copy(table, conn, keys, data_iter):
    # gets a DBAPI connection that can provide a cursor
    dbapi_conn = conn.connection
    with dbapi_conn.cursor() as cur:
        s_buf = StringIO()
        writer = csv.writer(s_buf)
        writer.writerows(data_iter)
        s_buf.seek(0)

        columns = ', '.join('"{}"'.format(k) for k in keys)
        if table.schema:
            table_name = '{}.{}'.format(table.schema, table.name)
        else:
            table_name = table.name

        sql = 'COPY {} ({}) FROM STDIN WITH CSV'.format(
            table_name, columns)
        cur.copy_expert(sql=sql, file=s_buf)

# %%
# прежде, чем заливать большую таблицу, лучше залить небольшой кусочек
df.sample(10).to_sql('german_credit', con, index=False, if_exists='replace',
                     method=psql_insert_copy)

# %%
def select(sql):
  return pd.read_sql(sql, con)

# %%
# Селект к таблице
sql = '''select * from german_credit t'''

# %%
select(sql)
# Out:
#    age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0   29    male    2     own          little             None           2743
# 1   30  female    2     own      quite rich         moderate           8358
# 2   28  female    2    rent            rich             None           2603
# 3   26    male    2     own            None             None           2069
# 4   33    male    1    rent          little         moderate           2384
# 5   43    male    1     own          little             None           7393
# 6   33  female    2     own          little         moderate           3244
# 7   31    male    1     own        moderate         moderate           9857
# 8   64  female    2     own          little         moderate            753
# 9   26    male    2     own          little           little           4788
#
#    duration              purpose  default         contract_dt  client_id
# 0        28             radio/TV        0 2007-08-08 17:47:59        426
# 1        48                  car        0 2008-04-30 16:52:53        945
# 2        24                  car        0 2008-02-09 15:56:45        733
# 3        10  furniture/equipment        0 2007-08-18 04:05:05         24
# 4        36              repairs        1 2007-08-29 20:44:34        583
# 5        24                  car        0 2008-04-18 10:35:09        971
# 6        18  furniture/equipment        0 2007-11-06 11:38:46        189
# 7        36             business        0 2007-07-12 01:25:41        684
# 8         6             radio/TV        0 2008-06-11 14:41:43        976
# 9        48                  car        0 2008-01-28 02:37:49        286

# %% [markdown]
# # Генерация таблиц

# %%
df = pd.DataFrame({'user_id': [1,2,3],
                   'user_name': ['a','b','c']})

# %%
df
# Out:
#    user_id user_name
# 0        1         a
# 1        2         b
# 2        3         c

# %%
con = sqlite3.connect('df')

# %%
df.to_sql('users', con, index=False, if_exists='replace')

# %%
sql = '''select * from users t'''

# %%
select(sql)
# Out:
#    user_id user_name
# 0        1         a
# 1        2         b
# 2        3         c

# %% [markdown]
# # Google Sheets

# %% [markdown]
# Cоздаем таблицу https://docs.google.com/spreadsheets/u/0/?tgif=d

# %% [markdown]
# Расшариваем:
# https://docs.google.com/spreadsheets/d/1spnR8j6t6v8h5SqlIQ8jPpbfkqjvIGqPJw6NLq0_2qg/edit?usp=sharing

# %% [markdown]
# Вытаскиваем id

# %%
id = '1spnR8j6t6v8h5SqlIQ8jPpbfkqjvIGqPJw6NLq0_2qg'

# %%
df = pd.read_csv(f'https://docs.google.com/spreadsheets/d/{id}/export?format=csv', on_bad_lines='skip')

# %%
df
# Out:
#    id name
# 0   2    q
# 1   3    w
# 2   4    e

# %%
df.to_sql('users2', con, index=False, if_exists='replace')

# %%
sql = '''select * from users2 t'''

# %%
select(sql)
# Out:
#    id name
# 0   2    q
# 1   3    w
# 2   4    e

# %% [markdown]
# # SELECT
# - where
# - between
# - order by
# - limit

# %%
df = pd.read_csv('/content/german_credit_augmented.csv')

# %%
df.head()
# Out:
#    age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0   33    male    2     own             NaN              NaN           3074
# 1   43    male    1     own          little           little           1344
# 2   52    male    2     own      quite rich              NaN            936
# 3   35  female    3     own          little              NaN           1393
# 4   28    male    2     own          little              NaN            776
#
#    duration    purpose  default          contract_dt  client_id
# 0         9   radio/TV        0  2008-06-29 18:52:00        210
# 1        12        car        0  2007-05-20 18:30:19        929
# 2         9  education        0  2008-04-27 08:23:07        200
# 3        11        car        0  2007-05-06 10:58:22         45
# 4        12   radio/TV        0  2007-07-21 13:22:14        358

# %%
# Обязательно нужно контролировать тип ДАТА, так как он заливается просто как текст
df['contract_dt'] = pd.to_datetime(df['contract_dt'], format='%Y-%m-%d %H:%M:%S')

# %%
df.dtypes
# Out:
# age                          int64
# sex                         object
# job                          int64
# housing                     object
# saving_accounts             object
# checking_account            object
# credit_amount                int64
# duration                     int64
# purpose                     object
# default                      int64
# contract_dt         datetime64[ns]
# client_id                    int64
# dtype: object

# %%
# сделали mount гугл-диска
# посмотрим что на диске
! ls '/content/drive/My Drive'
# Out:
#  Churn_Modelling.csv   german_credit.db   test-bd.gsheet
# 'Colab Notebooks'      hr_analytics.zip   UK-used-cars.zip

# %%
# создадим файл с базой данных на гугл-диске
con = sqlite3.connect('/content/drive/My Drive/german_credit.db')

# %%
! ls '/content/drive/My Drive'
# Out:
#  Churn_Modelling.csv   german_credit.db   test-bd.gsheet
# 'Colab Notebooks'      hr_analytics.zip   UK-used-cars.zip

# %%
df.to_sql('german_credit', con, index=False, if_exists='replace')

# %% [markdown]
# 1. Выбрать все

# %%
sql = '''select * from german_credit t'''

# %%
t = select(sql)
t.head()
# Out:
#    age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0   33    male    2     own            None             None           3074
# 1   43    male    1     own          little           little           1344
# 2   52    male    2     own      quite rich             None            936
# 3   35  female    3     own          little             None           1393
# 4   28    male    2     own          little             None            776
#
#    duration    purpose  default          contract_dt  client_id
# 0         9   radio/TV        0  2008-06-29 18:52:00        210
# 1        12        car        0  2007-05-20 18:30:19        929
# 2         9  education        0  2008-04-27 08:23:07        200
# 3        11        car        0  2007-05-06 10:58:22         45
# 4        12   radio/TV        0  2007-07-21 13:22:14        358

# %% [markdown]
# 2. Выбрать конкретные столбцы

# %%
# необходимо явно указывать из какой таблицы выбираются столбцы
# t - псевдоним основной таблицы

sql = '''select t.age, t.housing from german_credit t'''
t = select(sql)
t.head()
# Out:
#    age housing
# 0   33     own
# 1   43     own
# 2   52     own
# 3   35     own
# 4   28     own

# %%
# переименование столбца AS
# style guide рекомендует всегда использовать AS
# но удобно разлицать таблицы и столбцы, если у таблиц нет as, а у столбцов есть
sql = '''select t.age * 3 as age_mult3, t.housing from german_credit t'''
t = select(sql)
t.head()
# Out:
#    age_mult3 housing
# 0         99     own
# 1        129     own
# 2        156     own
# 3        105     own
# 4         84     own

# %%
# Вывести все существующие столбцы
sql = '''select t.* from german_credit t'''
t = select(sql)
t.head()
# Out:
#    age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0   33    male    2     own            None             None           3074
# 1   43    male    1     own          little           little           1344
# 2   52    male    2     own      quite rich             None            936
# 3   35  female    3     own          little             None           1393
# 4   28    male    2     own          little             None            776
#
#    duration    purpose  default          contract_dt  client_id
# 0         9   radio/TV        0  2008-06-29 18:52:00        210
# 1        12        car        0  2007-05-20 18:30:19        929
# 2         9  education        0  2008-04-27 08:23:07        200
# 3        11        car        0  2007-05-06 10:58:22         45
# 4        12   radio/TV        0  2007-07-21 13:22:14        358

# %%
# Создать новые столбцы перечисленные через запятую
sql = '''select t.age * 3 as age_mult3,
         t.age + t.credit_amount,
         t.age * 1.0/ t.credit_amount,
         t.age as age2,
         t.*
         from german_credit t''' # если не присвоить псевдоним, конструктор столбца будет в заголовке
t = select(sql)
t.head()

# часто при делении целого на целое база дает целое.
# Исправляем умножением числителя на 1.0

# t.age as age2 - скопировать столбец для каких-то манипуляций
# Out:
#    age_mult3  t.age + t.credit_amount  t.age * 1.0/ t.credit_amount  age2  \
# 0         99                     3107                      0.010735    33
# 1        129                     1387                      0.031994    43
# 2        156                      988                      0.055556    52
# 3        105                     1428                      0.025126    35
# 4         84                      804                      0.036082    28
#
#    age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0   33    male    2     own            None             None           3074
# 1   43    male    1     own          little           little           1344
# 2   52    male    2     own      quite rich             None            936
# 3   35  female    3     own          little             None           1393
# 4   28    male    2     own          little             None            776
#
#    duration    purpose  default          contract_dt  client_id
# 0         9   radio/TV        0  2008-06-29 18:52:00        210
# 1        12        car        0  2007-05-20 18:30:19        929
# 2         9  education        0  2008-04-27 08:23:07        200
# 3        11        car        0  2007-05-06 10:58:22         45
# 4        12   radio/TV        0  2007-07-21 13:22:14        358

# %%
# первые 5 строк таблицы
sql = '''select * from german_credit t limit 5'''
select(sql)
# Out:
#    age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0   33    male    2     own            None             None           3074
# 1   43    male    1     own          little           little           1344
# 2   52    male    2     own      quite rich             None            936
# 3   35  female    3     own          little             None           1393
# 4   28    male    2     own          little             None            776
#
#    duration    purpose  default          contract_dt  client_id
# 0         9   radio/TV        0  2008-06-29 18:52:00        210
# 1        12        car        0  2007-05-20 18:30:19        929
# 2         9  education        0  2008-04-27 08:23:07        200
# 3        11        car        0  2007-05-06 10:58:22         45
# 4        12   radio/TV        0  2007-07-21 13:22:14        358

# %%
# взять только 2007 год
# BETWEEN не включает верхнюю границу, когда в дате есть еще и время
# count - подсчет строк
sql = '''select count(*) from german_credit t 
where t.contract_dt between '2007-01-01' and '2008-01-01'
'''
select(sql)
# Out:
#    count(*)
# 0       575

# %%
# отсортировать по возрастанию
sql = '''select * from german_credit t 
where t.contract_dt between '2007-01-01' and '2008-01-01'
order by t.contract_dt
limit 5
'''
select(sql)
# Out:
#    age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0   20    male    2     own            None           little           2996
# 1   49  female    2     own          little         moderate           1092
# 2   30  female    3     own          little         moderate           4795
# 3   39  female    1     own            None         moderate            932
# 4   31    male    2     own          little             None           2775
#
#    duration              purpose  default          contract_dt  client_id
# 0        24  furniture/equipment        1  2007-05-01 07:17:29        495
# 1        12             radio/TV        0  2007-05-01 08:41:46        288
# 2        36             radio/TV        0  2007-05-01 12:42:45        141
# 3         6            education        0  2007-05-01 20:28:44        215
# 4        18                  car        1  2007-05-01 23:14:02        598

# %%
# отсортировать по убыванию
sql = '''select * from german_credit t 
where t.contract_dt between '2007-01-01' and '2008-01-01'
order by t.contract_dt desc
limit 5
'''
select(sql)
# Out:
#    age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0   61    male    1    rent        moderate         moderate           2767
# 1   37  female    2     own          little         moderate           3612
# 2   31  female    1     own          little             None           1736
# 3   35    male    1     own          little             None           2684
# 4   23  female    2    rent          little           little           2406
#
#    duration              purpose  default          contract_dt  client_id
# 0        21             business        1  2007-12-31 06:49:39        237
# 1        18  furniture/equipment        0  2007-12-31 02:58:16        537
# 2        12  furniture/equipment        0  2007-12-30 13:29:15        995
# 3        24             radio/TV        0  2007-12-30 00:40:33        256
# 4        30  furniture/equipment        1  2007-12-29 20:14:30        359

# %%
# отсортировать по двум столбцам - decs должен быть указан у каждого
sql = '''select * from german_credit t 
where t.contract_dt between '2007-01-01' and '2008-01-01'
order by t.contract_dt desc, t.credit_amount
'''
select(sql)
# Out:
#      age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0     61    male    1    rent        moderate         moderate           2767
# 1     37  female    2     own          little         moderate           3612
# 2     31  female    1     own          little             None           1736
# 3     35    male    1     own          little             None           2684
# 4     23  female    2    rent          little           little           2406
# ..   ...     ...  ...     ...             ...              ...            ...
# 570   31    male    2     own          little             None           2775
# 571   39  female    1     own            None         moderate            932
# 572   30  female    3     own          little         moderate           4795
# 573   49  female    2     own          little         moderate           1092
# 574   20    male    2     own            None           little           2996
#
#      duration              purpose  default          contract_dt  client_id
# 0          21             business        1  2007-12-31 06:49:39        237
# 1          18  furniture/equipment        0  2007-12-31 02:58:16        537
# 2          12  furniture/equipment        0  2007-12-30 13:29:15        995
# 3          24             radio/TV        0  2007-12-30 00:40:33        256
# 4          30  furniture/equipment        1  2007-12-29 20:14:30        359
# ..        ...                  ...      ...                  ...        ...
# 570        18                  car        1  2007-05-01 23:14:02        598
# 571         6            education        0  2007-05-01 20:28:44        215
# 572        36             radio/TV        0  2007-05-01 12:42:45        141
# 573        12             radio/TV        0  2007-05-01 08:41:46        288
# 574        24  furniture/equipment        1  2007-05-01 07:17:29        495
#
# [575 rows x 12 columns]

# %%
# отсортировать по двум столбцам - decs должен быть указан у каждого
sql = '''select t.contract_dt desc, t.credit_amount from german_credit t 
where t.contract_dt between '2007-01-01' and '2008-01-01'
order by t.contract_dt desc, t.credit_amount
'''
select(sql)
# Out:
#                     desc  credit_amount
# 0    2007-12-31 06:49:39           2767
# 1    2007-12-31 02:58:16           3612
# 2    2007-12-30 13:29:15           1736
# 3    2007-12-30 00:40:33           2684
# 4    2007-12-29 20:14:30           2406
# ..                   ...            ...
# 570  2007-05-01 23:14:02           2775
# 571  2007-05-01 20:28:44            932
# 572  2007-05-01 12:42:45           4795
# 573  2007-05-01 08:41:46           1092
# 574  2007-05-01 07:17:29           2996
#
# [575 rows x 2 columns]

# %%
# отбор по нескольким условиям
sql = '''select * from german_credit t 
where t.contract_dt between '2007-01-01' and '2008-01-01'
and t.purpose = 'car'
order by t.contract_dt desc, t.credit_amount
'''
select(sql)
# Out:
#      age   sex  job housing saving_accounts checking_account  credit_amount  \
# 0     36  male    3    rent            None         moderate           7057
# 1     25  male    2    rent        moderate         moderate           1264
# 2     48  male    2     own          little             None           2134
# 3     43  male    2    rent          little           little           4843
# 4     37  male    2    free            None         moderate          12389
# ..   ...   ...  ...     ...             ...              ...            ...
# 177   75  male    3    free          little           little           6615
# 178   55  male    2     own            rich             None           1413
# 179   47  male    3     own          little         moderate           1209
# 180   36  male    2     own          little         moderate            884
# 181   31  male    2     own          little             None           2775
#
#      duration purpose  default          contract_dt  client_id
# 0          20     car        0  2007-12-29 16:10:08         99
# 1          15     car        1  2007-12-28 08:38:58        979
# 2           9     car        0  2007-12-24 16:28:30         20
# 3          12     car        1  2007-12-22 16:17:29        668
# 4          36     car        1  2007-12-21 00:06:27        563
# ..        ...     ...      ...                  ...        ...
# 177        24     car        0  2007-05-06 09:37:45        330
# 178        12     car        0  2007-05-05 06:35:11        209
# 179         6     car        1  2007-05-03 10:29:01        485
# 180        18     car        1  2007-05-02 06:22:11        184
# 181        18     car        1  2007-05-01 23:14:02        598
#
# [182 rows x 12 columns]

# %%
# отбор по нескольким условиям,
# где одно из условий - выбор из множества вариантов
sql = '''select * from german_credit t 
where t.contract_dt between '2007-01-01' and '2008-01-01'
and t.purpose in ('car', 'repairs')
order by t.contract_dt desc, t.credit_amount
'''
select(sql)
# Out:
#      age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0     36    male    3    rent            None         moderate           7057
# 1     30    male    2     own          little         moderate            639
# 2     25    male    2    rent        moderate         moderate           1264
# 3     48    male    2     own          little             None           2134
# 4     67  female    2     own          little         moderate           3872
# ..   ...     ...  ...     ...             ...              ...            ...
# 192   55    male    2     own            rich             None           1413
# 193   55  female    0    free          little           little           1190
# 194   47    male    3     own          little         moderate           1209
# 195   36    male    2     own          little         moderate            884
# 196   31    male    2     own          little             None           2775
#
#      duration  purpose  default          contract_dt  client_id
# 0          20      car        0  2007-12-29 16:10:08         99
# 1          12  repairs        1  2007-12-28 17:09:43        127
# 2          15      car        1  2007-12-28 08:38:58        979
# 3           9      car        0  2007-12-24 16:28:30         20
# 4          18  repairs        0  2007-12-24 12:25:28        779
# ..        ...      ...      ...                  ...        ...
# 192        12      car        0  2007-05-05 06:35:11        209
# 193        18  repairs        1  2007-05-05 00:14:17        429
# 194         6      car        1  2007-05-03 10:29:01        485
# 195        18      car        1  2007-05-02 06:22:11        184
# 196        18      car        1  2007-05-01 23:14:02        598
#
# [197 rows x 12 columns]

# %%
# отбор по нескольким условиям,
# где одно из условий - выбор из множества вариантов
# вариант через OR - лучше не использовать
sql = '''select * from german_credit t 
where t.contract_dt between '2007-01-01' and '2008-01-01'
and (t.purpose='car' or t.purpose='repairs')
order by t.contract_dt desc, t.credit_amount
'''
select(sql)
# Out:
#      age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0     36    male    3    rent            None         moderate           7057
# 1     30    male    2     own          little         moderate            639
# 2     25    male    2    rent        moderate         moderate           1264
# 3     48    male    2     own          little             None           2134
# 4     67  female    2     own          little         moderate           3872
# ..   ...     ...  ...     ...             ...              ...            ...
# 192   55    male    2     own            rich             None           1413
# 193   55  female    0    free          little           little           1190
# 194   47    male    3     own          little         moderate           1209
# 195   36    male    2     own          little         moderate            884
# 196   31    male    2     own          little             None           2775
#
#      duration  purpose  default          contract_dt  client_id
# 0          20      car        0  2007-12-29 16:10:08         99
# 1          12  repairs        1  2007-12-28 17:09:43        127
# 2          15      car        1  2007-12-28 08:38:58        979
# 3           9      car        0  2007-12-24 16:28:30         20
# 4          18  repairs        0  2007-12-24 12:25:28        779
# ..        ...      ...      ...                  ...        ...
# 192        12      car        0  2007-05-05 06:35:11        209
# 193        18  repairs        1  2007-05-05 00:14:17        429
# 194         6      car        1  2007-05-03 10:29:01        485
# 195        18      car        1  2007-05-02 06:22:11        184
# 196        18      car        1  2007-05-01 23:14:02        598
#
# [197 rows x 12 columns]

# %% [markdown]
# #LIKE

# %%
df = pd.DataFrame({'purpose': ['машина', 'на машину', 'на покупку машины', 'автомобиль', 'на возвращение 2007'],
                   'credit': [1000, 400, 600, 700, 1500]})

# %%
df
# Out:
#                purpose  credit
# 0               машина    1000
# 1            на машину     400
# 2    на покупку машины     600
# 3           автомобиль     700
# 4  на возвращение 2007    1500

# %%
df.to_sql('purpose', con, index=False, if_exists='replace')

# %%
sql = '''select * from purpose t'''

# %%
select(sql)
# Out:
#                purpose  credit
# 0               машина    1000
# 1            на машину     400
# 2    на покупку машины     600
# 3           автомобиль     700
# 4  на возвращение 2007    1500

# %%
# like умеет мэтчить шабллоны строк

sql = '''select * from purpose t
where (t.purpose like '%машин%' or t.purpose like '%авто%')
and t.credit > 500
'''
select(sql)
# Out:
#              purpose  credit
# 0             машина    1000
# 1  на покупку машины     600
# 2         автомобиль     700

# %% [markdown]
# #УСЛОВИЯ
# - case when
# - iif
# - avg - среднее

# %%
# Лучше всегда указывать перед * таблицу, откуда достаются все поля
# в дальнейшем, когда будем джойнить несколько таблиц просто * будет означать все поля всех таблиц

# %% [markdown]
# Задача:
#
# Посчитать долю клиентов, у которых размер кредита > 1000

# %%
sql = '''select * from german_credit t'''

# %%
select(sql).head()
# Out:
#    age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0   33    male    2     own            None             None           3074
# 1   43    male    1     own          little           little           1344
# 2   52    male    2     own      quite rich             None            936
# 3   35  female    3     own          little             None           1393
# 4   28    male    2     own          little             None            776
#
#    duration    purpose  default          contract_dt  client_id
# 0         9   radio/TV        0  2008-06-29 18:52:00        210
# 1        12        car        0  2007-05-20 18:30:19        929
# 2         9  education        0  2008-04-27 08:23:07        200
# 3        11        car        0  2007-05-06 10:58:22         45
# 4        12   radio/TV        0  2007-07-21 13:22:14        358

# %%
# количество строк в таблице
sql = '''select count(*) from german_credit t'''
select(sql)
# Out:
#    count(*)
# 0      1000

# %%
# количество клиентов с кредитом > 1000
sql = '''select count(*) from german_credit t
where t.credit_amount > 1000
'''
select(sql)
# Out:
#    count(*)
# 0       884

# %%
# поле ФЛАГ (1 или 0)
sql = '''select t.credit_amount,
case when t.credit_amount > 1000 then 1 else 0 end
from german_credit t

'''
select(sql)
# Out:
#      credit_amount  case when t.credit_amount > 1000 then 1 else 0 end
# 0             3074                                                  1
# 1             1344                                                  1
# 2              936                                                  0
# 3             1393                                                  1
# 4              776                                                  0
# ..             ...                                                ...
# 995           2600                                                  1
# 996           4455                                                  1
# 997           6403                                                  1
# 998           5003                                                  1
# 999           1804                                                  1
#
# [1000 rows x 2 columns]

# %%
# поле ФЛАГ (1 или 0) другой вариант
sql = '''select t.credit_amount,
case when t.credit_amount > 1000 then 1 else 0 end as greater_100_flag,
iif(t.credit_amount > 1000, 1, 0) as greater_100_flag2
from german_credit t

'''
select(sql)
# Out:
#      credit_amount  greater_100_flag  greater_100_flag2
# 0             3074                 1                  1
# 1             1344                 1                  1
# 2              936                 0                  0
# 3             1393                 1                  1
# 4              776                 0                  0
# ..             ...               ...                ...
# 995           2600                 1                  1
# 996           4455                 1                  1
# 997           6403                 1                  1
# 998           5003                 1                  1
# 999           1804                 1                  1
#
# [1000 rows x 3 columns]

# %%
# чтобы рассчитать долю нужно взять среднее по столбцу флаг

sql = '''select avg(case when t.credit_amount > 1000 then 1 else 0 end) as greater_fraction
from german_credit t
'''
select(sql)
# Out:
#    greater_fraction
# 0             0.884

# %% [markdown]
# #Cursor
# - drop
# - create
#
# Сохранить результат селекта в отдельную таблицу

# %%
sql = '''select * from german_credit t
where t.credit_amount > 1000'''
select(sql).head()
# Out:
#    age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0   33    male    2     own            None             None           3074
# 1   43    male    1     own          little           little           1344
# 2   35  female    3     own          little             None           1393
# 3   27  female    2     own          little         moderate           1295
# 4   26    male    2     own          little           little           4370
#
#    duration              purpose  default          contract_dt  client_id
# 0         9             radio/TV        0  2008-06-29 18:52:00        210
# 1        12                  car        0  2007-05-20 18:30:19        929
# 2        11                  car        0  2007-05-06 10:58:22         45
# 3        18  furniture/equipment        0  2008-06-18 04:10:05         86
# 4        42             radio/TV        1  2007-11-29 00:20:44        639

# %%
# Сохраняем результат селекта в отдельную таблицу, предварительно дропнув ее на всякий случай(для перезаписи)
cur = con.cursor()

sql = '''
drop table if exists greater_1000_credit;

create table greater_1000_credit as
select * from german_credit t
where t.credit_amount > 1000'''

# %%
cur.executescript(sql)

# %%
sql = '''select * from greater_1000_credit t'''
select(sql).head()
# Out:
#    age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0   33    male    2     own            None             None           3074
# 1   43    male    1     own          little           little           1344
# 2   35  female    3     own          little             None           1393
# 3   27  female    2     own          little         moderate           1295
# 4   26    male    2     own          little           little           4370
#
#    duration              purpose  default          contract_dt  client_id
# 0         9             radio/TV        0  2008-06-29 18:52:00        210
# 1        12                  car        0  2007-05-20 18:30:19        929
# 2        11                  car        0  2007-05-06 10:58:22         45
# 3        18  furniture/equipment        0  2008-06-18 04:10:05         86
# 4        42             radio/TV        1  2007-11-29 00:20:44        639

# %% [markdown]
# Создание таблицы в postgress

# %%
from sqlalchemy import create_engine
con_pg = create_engine('postgresql+psycopg2://mzsexmlj:HnO7Ku7fy_6VCtQM9uUSVECvXKc4WILU@abul.db.elephantsql.com/mzsexmlj')

# %%
# загружаем csv-таблицу с гугл-диска
# !gdown --id 1Gj0qVU0Acv-HqRjTIEwvkO4TqJYijehR
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1Gj0qVU0Acv-HqRjTIEwvkO4TqJYijehR
# To: /content/german_credit_augmented.csv
# 100% 69.6k/69.6k [00:00<00:00, 45.9MB/s]

# %%
df = pd.read_csv('/content/german_credit_augmented.csv')

# %%
df.to_sql('german_credit', con_pg, index=False, if_exists='replace',
                     method=psql_insert_copy)

# %%
def select_pg(sql):
  return pd.read_sql(sql, con_pg)

# %%
# Селект к таблице
sql = '''select * from german_credit t'''

# %%
select_pg(sql)
# Out:
#      age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0     33    male    2     own            None             None           3074
# 1     43    male    1     own          little           little           1344
# 2     52    male    2     own      quite rich             None            936
# 3     35  female    3     own          little             None           1393
# 4     28    male    2     own          little             None            776
# ..   ...     ...  ...     ...             ...              ...            ...
# 995   65    male    2    free          little           little           2600
# 996   30    male    3     own          little         moderate           4455
# 997   33    male    2     own          little         moderate           6403
# 998   29  female    2     own            None             None           5003
# 999   44    male    2     own        moderate         moderate           1804
#
#      duration    purpose  default          contract_dt  client_id
# 0           9   radio/TV        0  2008-06-29 18:52:00        210
# 1          12        car        0  2007-05-20 18:30:19        929
# 2           9  education        0  2008-04-27 08:23:07        200
# 3          11        car        0  2007-05-06 10:58:22         45
# 4          12   radio/TV        0  2007-07-21 13:22:14        358
# ..        ...        ...      ...                  ...        ...
# 995        18   radio/TV        1  2007-12-16 20:17:19        624
# 996        36   business        1  2007-07-12 14:08:58        181
# 997        24   radio/TV        0  2008-04-08 03:24:26        730
# 998        21        car        1  2007-11-29 15:51:45        557
# 999        12        car        0  2007-08-14 09:05:33         23
#
# [1000 rows x 12 columns]

# %%
# В sqlalchemy у engine сразу есть функция execute

sql = '''
drop table if exists greater_1000_credit;

create table greater_1000_credit as
select * from german_credit t
where t.credit_amount > 1000
'''

# %%
con_pg.execute(sql) # по умолчанию выполняет несколько команд

# %%
sql = '''select * from greater_1000_credit'''
select_pg(sql)
# Out:
#      age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0     33    male    2     own            None             None           3074
# 1     43    male    1     own          little           little           1344
# 2     35  female    3     own          little             None           1393
# 3     27  female    2     own          little         moderate           1295
# 4     26    male    2     own          little           little           4370
# ..   ...     ...  ...     ...             ...              ...            ...
# 879   65    male    2    free          little           little           2600
# 880   30    male    3     own          little         moderate           4455
# 881   33    male    2     own          little         moderate           6403
# 882   29  female    2     own            None             None           5003
# 883   44    male    2     own        moderate         moderate           1804
#
#      duration              purpose  default          contract_dt  client_id
# 0           9             radio/TV        0  2008-06-29 18:52:00        210
# 1          12                  car        0  2007-05-20 18:30:19        929
# 2          11                  car        0  2007-05-06 10:58:22         45
# 3          18  furniture/equipment        0  2008-06-18 04:10:05         86
# 4          42             radio/TV        1  2007-11-29 00:20:44        639
# ..        ...                  ...      ...                  ...        ...
# 879        18             radio/TV        1  2007-12-16 20:17:19        624
# 880        36             business        1  2007-07-12 14:08:58        181
# 881        24             radio/TV        0  2008-04-08 03:24:26        730
# 882        21                  car        1  2007-11-29 15:51:45        557
# 883        12                  car        0  2007-08-14 09:05:33         23
#
# [884 rows x 12 columns]
